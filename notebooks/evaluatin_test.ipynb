# %%
import importlib
import sys
import os
import mlflow

# %%
sys.path.append(os.path.abspath(os.path.join('..', 'src')))

from predict.final_test_evaluator import FinalTestEvaluator
from predict.acuuracy import ModelEvaluator

import predict.final_test_evaluator
import predict.acuuracy

importlib.reload(predict.acuuracy)
importlib.reload(predict.final_test_evaluator)
# Out:
# <module 'predict.final_test_evaluator' from '/Users/level3/mlops_spotify/spotify-1million/src/predict/final_test_evaluator.py'>

# %%
tracking_uri = "http://localhost:5000"
model_name =  "models:/SpotifyPopularityClassifier@production"
target_name = "popularity"
database_path = "../data/test/test.csv"
expirement_name = "Spotify_final_test"

# %%
mlflow.set_tracking_uri(tracking_uri)
evaluator = FinalTestEvaluator(
    test_data_path= database_path,
    target_column= target_name,
    model_uri= model_name,
    evaluator_class=ModelEvaluator,
    expirement_name=expirement_name
)

results = evaluator.run()
# Out:
# [WARN] Model URI must be in format models:/<name>/<version_or_stage>
# ...
# Invalid model URI format for tagging.
# 🏃 View run dazzling-kite-366 at: http://localhost:5000/#/experiments/228659400308854583/runs/67d95e7dd057467db87c6fd5a60edd1c
# 🧪 View experiment at: http://localhost:5000/#/experiments/228659400308854583

# %%
# View results
results["accuracy"]
# Out:
# 0.8356048713191571

# %%
tracking_uri = "http://localhost:5000"
model_name =  "models:/SpotifyPopularityClassifier@production"
target_name = "popularity"
database_path = "../data/data_2023/data_2023.csv"
expirement_name = "Spotify_final_test"

# %%
mlflow.set_tracking_uri(tracking_uri)
evaluator_2023 = FinalTestEvaluator(
    test_data_path= database_path,
    target_column= target_name,
    model_uri= model_name,
    evaluator_class=ModelEvaluator,
    expirement_name=expirement_name
)

results = evaluator_2023.run()
# Out:
# [WARN] Model URI must be in format models:/<name>/<version_or_stage>
# ...
# /Users/level3/mlops_spotify/spotify-1million/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/level3/mlops_spotify/spotify-1million/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
evaluator_2023.get_prediction_probabilities()
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
import pandas as pd
df_2023 = pd.read_csv(database_path)
df_2023
# Out:
#                         artist_name  \
# 0                        Jason Mraz
# 1      Drew Holcomb & The Neighbors
# 2                      Wilder Woods
# 3                      Wilder Woods
# 4                        Ben Rector
# ...                             ...
# 38644                    Lemongrass
# 38645                 Groove Armada
# 38646               Brazilian Girls
# 38647               Brazilian Girls
# 38648    The Future Sound Of London
#
#                                               track_name  \
# 0                                    I Feel Like Dancing
# 1                                       Find Your People
# 2                                            Get It Back
# 3                              Maestro (Tears Don't Lie)
# 4                                Range Rover (A Capella)
# ...                                                  ...
# 38644                                     Grapes - Remix
# 38645  Rescue Me - Roland Leesker's You Got To Dance ...
# ...
